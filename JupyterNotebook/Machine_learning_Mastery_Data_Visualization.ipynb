# %%
from pandas import set_option
from pandas import read_csv

# %%
from pandas import read_csv

names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class'] 
data = read_csv('pima-indians-diabetes.data.csv',names = names)

# %%
data.head(20)
# Out:
#            preg     plas           pres           skin     test  mass  \
# 0   Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1             6      148             72             35        0  33.6
# 2             1       85             66             29        0  26.6
# 3             8      183             64              0        0  23.3
# 4             1       89             66             23       94  28.1
# 5             0      137             40             35      168  43.1
# 6             5      116             74              0        0  25.6
# 7             3       78             50             32       88    31
# 8            10      115              0              0        0  35.3
# 9             2      197             70             45      543  30.5
# 10            8      125             96              0        0     0
# 11            4      110             92              0        0  37.6
# 12           10      168             74              0        0    38
# 13           10      139             80              0        0  27.1
# 14            1      189             60             23      846  30.1
# 15            5      166             72             19      175  25.8
# 16            7      100              0              0        0    30
# 17            0      118             84             47      230  45.8
# 18            7      107             74              0        0  29.6
# 19            1      103             30             38       83  43.3
#
#                         pedi  age    class
# 0   DiabetesPedigreeFunction  Age  Outcome
# 1                      0.627   50        1
# 2                      0.351   31        0
# 3                      0.672   32        1
# 4                      0.167   21        0
# 5                      2.288   33        1
# 6                      0.201   30        0
# 7                      0.248   26        1
# 8                      0.134   29        0
# 9                      0.158   53        1
# 10                     0.232   54        1
# 11                     0.191   30        0
# 12                     0.537   34        1
# 13                     1.441   57        0
# 14                     0.398   59        1
# 15                     0.587   51        1
# 16                     0.484   32        1
# 17                     0.551   31        1
# 18                     0.254   31        1
# 19                     0.183   33        0

# %%
## Univariate plots
#   histograms/ Density plots/ box and whisker plots
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style("whitegrid");
sns.pairplot('pima-indians-diabetes.data.csv');
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-3e515745c095> in <module>
#       1 sns.set_style("whitegrid");
# ----> 2 sns.pairplot('pima-indians-diabetes.data.csv');
#       3 plt.show()
#
# C:\Anaconda3\envs\Learning_ML\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2082         raise TypeError(
#    2083             "'data' must be pandas DataFrame object, not: {typefound}".format(
# -> 2084                 typefound=type(data)))
#    2085
#    2086     plot_kws = {} if plot_kws is None else plot_kws.copy()
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'str'>
