# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
x = np.array([-5,0,5,10,15,25,35,45,55]).reshape((-1,1))
y = np.array([-10,-5,0,5,20,30,40,50,60])

# %%
regressor = LinearRegression().fit(x,y)
y_pred = regressor.predict(x)
print('Coefficient of determination: ',regressor.score(x,y))
print('intercept: ',regressor.intercept_)
print('slope: ',regressor.coef_)
# Out:
# Coefficient of determination:  0.9859891891891892
# intercept:  -3.7200000000000024
# slope:  [1.208]

# %%
fig = plt.figure()
fig.add_axes([0,0,1,1])
plt.scatter(x,y,color='r')
plt.plot(x,y_pred, color='b')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Simple Linear Regression')
plt.show()
